# %% [markdown]
# # Exercise session 2, Exercise 3
#
# This is a template for using the [pysat](https://pysathq.github.io/) Python library to call a SAT solver to work out Exercise 3 for *Exercise session 2*.
#
# First, install pysat, e.g., using:
# `python -m pip install --upgrade --user python-sat`
#
# Let's start with importing some relevant and useful things (from the pysat library):

# %%
from pysat.formula import CNF
from pysat.solvers import MinisatGH

from itertools import product
from itertools import combinations

# %% [markdown]
# ## Exercise 3
#
# ### Setting things up
# With pysat, we can only have variables that are identified with a single positive integer. To make things a bit more convenient, let us introduce a way to identify variables by names that make intuitive sense.

# %%
varnum_to_varcolor = dict()
varcolor_to_varnum = dict()

def generate_numbers(n):
    return [i for i in range(1, n+1)]
    
numbers = generate_numbers(10)
colors = ['a', 'b']

for num, color in enumerate(product(numbers, colors), 1):
    varnum_to_varcolor[num] = color
    varcolor_to_varnum[color] = num

# %% [markdown]
# Now we can construct a CNF formula.

# %%
formula = CNF()

# %% [markdown]
# Let's begin by adding clauses that state that every number is assigned exactly one color.

# %%
# Each number is assigned to some color
for num in numbers:
    clause = [varcolor_to_varnum[(num, col)] for col in colors]
    formula.append(clause)

# %% [markdown]
# ### Finish the formula
# The formula is not finished yet. Complete the formula by adding more clauses.

# %%
# Function to check if a triple forms a Pythagorean triple
def is_pythagorean_triple(a, b, c):
    return a**2 + b**2 == c**2

# %%
# Each number is assigned exactly one color.
for num in numbers:
    for col1, col2 in combinations(colors, r=2):
        clause = [
            -1*varcolor_to_varnum[(num, col1)],
            -1*varcolor_to_varnum[(num, col2)]
        ]
        formula.append(clause)

# No Pythagorean triple has all three numbers with all the same color.
for num1, num2, num3 in combinations(numbers, r=3):
    if is_pythagorean_triple(num1, num2, num3):
        for col in colors:
            clause = [
                -1*varcolor_to_varnum[(num1, col)],
                -1*varcolor_to_varnum[(num2, col)],
                -1*varcolor_to_varnum[(num3, col)]
            ]
            formula.append(clause)

# %% [markdown]
# Let's see how many (and which) models remain.

# %%
solver = MinisatGH()
solver.append_formula(formula)

for i, model in enumerate(solver.enum_models(), 1):
    print(f"Found a satisfying assignment (#{i}):");
    for lit in model:
        if lit > 0:
            num, color = varnum_to_varcolor[lit]
            print(f"- {num} assigned color {color}")
    print()
# Out:
# Found a satisfying assignment (#1):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#2):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#3):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#4):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#5):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#6):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#7):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#8):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#9):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#10):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#11):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#12):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#13):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#14):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#15):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#16):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#17):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#18):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#19):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#20):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#21):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#22):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#23):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#24):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#25):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#26):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#27):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#28):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#29):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#30):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#31):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#32):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#33):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#34):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#35):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#36):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#37):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#38):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#39):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#40):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#41):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#42):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#43):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#44):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#45):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#46):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#47):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#48):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#49):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#50):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#51):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#52):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#53):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#54):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#55):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#56):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#57):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#58):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#59):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#60):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#61):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#62):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#63):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#64):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#65):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#66):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#67):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#68):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#69):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#70):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#71):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#72):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#73):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#74):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#75):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#76):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#77):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#78):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#79):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#80):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#81):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#82):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#83):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#84):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#85):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#86):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#87):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#88):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#89):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#90):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#91):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#92):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#93):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#94):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#95):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#96):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#97):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#98):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#99):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#100):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#101):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#102):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#103):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#104):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#105):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#106):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#107):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#108):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#109):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#110):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#111):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#112):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#113):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#114):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#115):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#116):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#117):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#118):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#119):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#120):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#121):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#122):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#123):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#124):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#125):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#126):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#127):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#128):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#129):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#130):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#131):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#132):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#133):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#134):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#135):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#136):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#137):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#138):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#139):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#140):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#141):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#142):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#143):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#144):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#145):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#146):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#147):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#148):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#149):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#150):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#151):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#152):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#153):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#154):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#155):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#156):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#157):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#158):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#159):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#160):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#161):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#162):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#163):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#164):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#165):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#166):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#167):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#168):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#169):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#170):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#171):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#172):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#173):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#174):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#175):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#176):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#177):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#178):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#179):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#180):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#181):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#182):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#183):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#184):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#185):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#186):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#187):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#188):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#189):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#190):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#191):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#192):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#193):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color a
# ...
#
# Found a satisfying assignment (#513):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#514):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#515):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#516):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#517):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#518):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#519):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#520):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#521):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#522):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#523):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#524):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#525):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#526):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#527):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#528):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#529):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#530):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#531):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#532):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#533):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#534):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#535):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#536):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#537):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#538):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#539):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#540):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#541):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#542):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#543):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#544):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#545):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#546):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#547):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#548):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#549):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#550):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#551):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#552):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#553):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#554):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#555):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#556):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#557):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color a
# - 10 assigned color b
#
# Found a satisfying assignment (#558):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color a
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#559):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#560):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#561):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#562):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#563):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#564):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#565):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#566):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color a
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#567):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#568):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#569):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color b
# - 10 assigned color a
#
# Found a satisfying assignment (#570):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color a
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#571):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color a
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#572):
# - 1 assigned color a
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#573):
# - 1 assigned color a
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color b
# - 6 assigned color a
# - 7 assigned color b
# - 8 assigned color b
# - 9 assigned color a
# - 10 assigned color a
#
# Found a satisfying assignment (#574):
# - 1 assigned color b
# - 2 assigned color a
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#575):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color b
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color b
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
#
# Found a satisfying assignment (#576):
# - 1 assigned color b
# - 2 assigned color b
# - 3 assigned color b
# - 4 assigned color a
# - 5 assigned color a
# - 6 assigned color b
# - 7 assigned color a
# - 8 assigned color a
# - 9 assigned color b
# - 10 assigned color b
